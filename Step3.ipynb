# %%
import findspark
findspark.init('/home/ubuntu/spark-2.1.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import *
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
spark = SparkSession.builder.appName('Step3').getOrCreate()

# %%
import pandas as pd
import numpy as np

# %%
lp_data = pd.read_csv('Dataset_main/litecoin_price (1).csv')
ep_data = pd.read_csv('Dataset_main/ethereum_classic_price 1.csv')

# %%
print(lp_data.columns)
lp_data.head(5)

lp_data.columns = ['Date', 'Open_litecoin','High_litecoin', 'Low_litecoin', 'Close_litecoin', 'Volume_litecoin', 'Market_Cap_litecoin']
lp_data.head()
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')
#            Date  Open_litecoin  High_litecoin  Low_litecoin  Close_litecoin  \
# 0  Feb 20, 2018         223.09         253.90        222.51          232.85
# 1  Feb 19, 2018         215.41         226.97        215.38          223.06
# 2  Feb 18, 2018         230.51         232.64        214.46          215.74
# 3  Feb 17, 2018         229.50         233.45        225.60          229.47
# 4  Feb 16, 2018         225.50         236.09        212.33          230.12
#
#   Volume_litecoin Market_Cap_litecoin
# 0  1,73,96,70,000     12,33,51,00,000
# 1    76,75,97,000     11,90,79,00,000
# 2  1,01,11,20,000     12,73,88,00,000
# 3    86,34,01,000     12,67,97,00,000
# 4  1,30,00,90,000     12,45,53,00,000

# %%
print(ep_data.columns)
ep_data.head(5)

ep_data.columns = ['Date', 'Open_ethereum','High_ethereum', 'Low_ethereum', 'Close_ethereum', 'Volume_ethereum', 'Market_Cap_ethereum']
ep_data.head()
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')
#            Date  Open_ethereum  High_ethereum  Low_ethereum  Close_ethereum  \
# 0  Feb 20, 2018          39.41          43.96         38.23           38.47
# 1  Feb 19, 2018          34.69          40.26         33.93           39.29
# 2  Feb 18, 2018          35.01          35.08         31.52           34.88
# 3  Feb 17, 2018          34.97          35.40         34.38           34.99
# 4  Feb 16, 2018          34.43          35.34         32.90           35.03
#
#   Volume_ethereum Market_Cap_ethereum
# 0  1,17,58,90,000      3,94,00,10,000
# 1    99,22,56,000      3,46,78,60,000
# 2    45,68,29,000      3,49,83,90,000
# 3    41,85,34,000      3,49,36,50,000
# 4    45,67,54,000      3,43,91,80,000

# %%
import pandas as pd
lp=pd.read_csv('Dataset_main/litecoin_price (1).csv',index_col='Date')
lp.head()
lp_data.columns = ['Date', 'Open_litecoin','High_litecoin', 'Low_litecoin', 'Close_litecoin', 'Volume_litecoin', 'Market_Cap_litecoin']
lp_data.head()
ep=pd.read_csv('Dataset_main/ethereum_classic_price 1.csv',index_col='Date')
ep.head()
ep_data.columns = ['Date', 'Open_ethereum','High_ethereum', 'Low_ethereum', 'Close_ethereum', 'Volume_ethereum', 'Market_Cap_ethereum']
ep_data.head()
merged_pandas=lp.merge(ep, on='Date', how='outer')
merged_pandas.head()
# Out:
#               Open_x  High_x   Low_x  Close_x        Volume_x  \
# Date
# Feb 20, 2018  223.09  253.90  222.51   232.85  1,73,96,70,000
# Feb 19, 2018  215.41  226.97  215.38   223.06    76,75,97,000
# Feb 18, 2018  230.51  232.64  214.46   215.74  1,01,11,20,000
# Feb 17, 2018  229.50  233.45  225.60   229.47    86,34,01,000
# Feb 16, 2018  225.50  236.09  212.33   230.12  1,30,00,90,000
#
#                  Market Cap_x  Open_y  High_y  Low_y  Close_y        Volume_y  \
# Date
# Feb 20, 2018  12,33,51,00,000   39.41   43.96  38.23    38.47  1,17,58,90,000
# Feb 19, 2018  11,90,79,00,000   34.69   40.26  33.93    39.29    99,22,56,000
# Feb 18, 2018  12,73,88,00,000   35.01   35.08  31.52    34.88    45,68,29,000
# Feb 17, 2018  12,67,97,00,000   34.97   35.40  34.38    34.99    41,85,34,000
# Feb 16, 2018  12,45,53,00,000   34.43   35.34  32.90    35.03    45,67,54,000
#
#                 Market Cap_y
# Date
# Feb 20, 2018  3,94,00,10,000
# Feb 19, 2018  3,46,78,60,000
# Feb 18, 2018  3,49,83,90,000
# Feb 17, 2018  3,49,36,50,000
# Feb 16, 2018  3,43,91,80,000

# %%
lp_data.columns = ['Date', 'Open_litecoin','High_litecoin', 'Low_litecoin', 'Close_litecoin', 'Volume_litecoin', 'Market_Cap_litecoin']
lp_data.head()
# Out:
#            Date  Open_litecoin  High_litecoin  Low_litecoin  Close_litecoin  \
# 0  Feb 20, 2018         223.09         253.90        222.51          232.85
# 1  Feb 19, 2018         215.41         226.97        215.38          223.06
# 2  Feb 18, 2018         230.51         232.64        214.46          215.74
# 3  Feb 17, 2018         229.50         233.45        225.60          229.47
# 4  Feb 16, 2018         225.50         236.09        212.33          230.12
#
#   Volume_litecoin Market_Cap_litecoin
# 0  1,73,96,70,000     12,33,51,00,000
# 1    76,75,97,000     11,90,79,00,000
# 2  1,01,11,20,000     12,73,88,00,000
# 3    86,34,01,000     12,67,97,00,000
# 4  1,30,00,90,000     12,45,53,00,000

# %%
ep_data.columns = ['Date', 'Open_ethereum','High_ethereum', 'Low_ethereum', 'Close_ethereum', 'Volume_ethereum', 'Market_Cap_ethereum']
ep_data.head()
# Out:
#            Date  Open_ethereum  High_ethereum  Low_ethereum  Close_ethereum  \
# 0  Feb 20, 2018          39.41          43.96         38.23           38.47
# 1  Feb 19, 2018          34.69          40.26         33.93           39.29
# 2  Feb 18, 2018          35.01          35.08         31.52           34.88
# 3  Feb 17, 2018          34.97          35.40         34.38           34.99
# 4  Feb 16, 2018          34.43          35.34         32.90           35.03
#
#   Volume_ethereum Market_Cap_ethereum
# 0  1,17,58,90,000      3,94,00,10,000
# 1    99,22,56,000      3,46,78,60,000
# 2    45,68,29,000      3,49,83,90,000
# 3    41,85,34,000      3,49,36,50,000
# 4    45,67,54,000      3,43,91,80,000

# %%
merged_pandas_final=lp_data.merge(ep_data, on='Date', how='outer')
merged_pandas_final.head()
# Out:
#            Date  Open_litecoin  High_litecoin  Low_litecoin  Close_litecoin  \
# 0  Feb 20, 2018         223.09         253.90        222.51          232.85
# 1  Feb 19, 2018         215.41         226.97        215.38          223.06
# 2  Feb 18, 2018         230.51         232.64        214.46          215.74
# 3  Feb 17, 2018         229.50         233.45        225.60          229.47
# 4  Feb 16, 2018         225.50         236.09        212.33          230.12
#
#   Volume_litecoin Market_Cap_litecoin  Open_ethereum  High_ethereum  \
# 0  1,73,96,70,000     12,33,51,00,000          39.41          43.96
# 1    76,75,97,000     11,90,79,00,000          34.69          40.26
# 2  1,01,11,20,000     12,73,88,00,000          35.01          35.08
# 3    86,34,01,000     12,67,97,00,000          34.97          35.40
# 4  1,30,00,90,000     12,45,53,00,000          34.43          35.34
#
#    Low_ethereum  Close_ethereum Volume_ethereum Market_Cap_ethereum
# 0         38.23           38.47  1,17,58,90,000      3,94,00,10,000
# 1         33.93           39.29    99,22,56,000      3,46,78,60,000
# 2         31.52           34.88    45,68,29,000      3,49,83,90,000
# 3         34.38           34.99    41,85,34,000      3,49,36,50,000
# 4         32.90           35.03    45,67,54,000      3,43,91,80,000
